# %%
import os
from typing import List, Tuple
from dotenv import load_dotenv

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.runnables import (
    RunnableParallel,
)
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_openai import ChatOpenAI

from zep_cloud.client import AsyncZep, Zep
from langchain_community.chat_message_histories.zep import ZepChatMessageHistory

load_dotenv()
api_key = os.getenv("DEEPSEEK_API_KEY")

client = AsyncZep(
    api_key=os.environ["ZEP_API_KEY"],
)

new_user = await client.user.add(
        user_id="test1",
        email="123123@example.com",
        first_name="Tenison",
        last_name="Teng",
        metadata={"user_name": "tension", "age": 22, "gender": "male"},
    )

# %%
memory = await client.memory.add_session(session_id="demo1", user_id=new_user.user_id)
# Out:
# Session(classifications=None, created_at='2024-08-27T07:29:00.79886Z', deleted_at=None, ended_at=None, fact_rating_instruction=None, fact_version_uuid=None, facts=None, id=2, metadata=None, project_uuid='00000000-0000-0000-0000-000000000000', session_id='demo1', updated_at='2024-08-27T07:29:00.79886Z', user_id='test1', uuid_='9e8daa5a-c297-4171-979e-769dd194e261')

# %%
await client.memory.get()
# Out:
# SessionListResponse(response_count=1, sessions=[Session(classifications=None, created_at='2024-08-27T07:29:00.79886Z', deleted_at=None, ended_at=None, fact_rating_instruction=None, fact_version_uuid=None, facts=None, id=2, metadata=None, project_uuid='00000000-0000-0000-0000-000000000000', session_id='demo1', updated_at='2024-08-27T07:29:00.79886Z', user_id='test1', uuid_='9e8daa5a-c297-4171-979e-769dd194e261')], total_count=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 81
#      58 model = ChatOpenAI(
#      59     model="deepseek-chat",
#      60     api_key=api_key,
#    (...)
#      64     verbose=True,
#      65 )
#      69 chain = RunnableWithMessageHistory(
#      70     answer_prompt| model | StrOutputParser(),
#      71     lambda session_id: ZepChatMessageHistory(
#    (...)
#      78     history_messages_key="chat_history",
#      79 )
# ---> 81 response = chain.invoke(
#      82     {"question": "你好，好久不见"},
#      83     config={"configurable": {"session_id": "demo1"}},
#      84 )
#      86 print(response)
#
# File ~/miniconda3/envs/graph/lib/python3.10/site-packages/langchain_core/runnables/base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
# ...
